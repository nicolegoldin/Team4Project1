# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from pathlib import Path
import csv

# %%
stock_csv_path = Path('monthly_data.csv')
monthly_df = pd.read_csv(stock_csv_path, index_col = 'Date')
monthly_df_daily_returns = monthly_df.pct_change()

# %%
monthly_df_daily_returns.head()
# Out:
#               DXC       BBY       AMG       CNP       WMT       MRK       NEM  \
# Date
# 3/31/15       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4/30/15 -0.012714 -0.083091  0.052845  0.027437 -0.051064  0.036186  0.220175
# 5/31/15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6/30/15  0.025611 -0.052519 -0.033299 -0.081165 -0.085489 -0.036887 -0.117304
# 7/31/15 -0.003199 -0.009813 -0.048948  0.016290  0.014804  0.035658 -0.264983
#
#               VFC       MDT       HST  ...       UNH       HSY        FB  \
# Date                                   ...
# 3/31/15       NaN       NaN       NaN  ...       NaN       NaN       NaN
# 4/30/15 -0.038242 -0.045391 -0.001982  ... -0.058247 -0.089090 -0.041961
# 5/31/15  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 6/30/15 -0.032477  0.000349 -0.005595  ...  0.099791 -0.028147  0.088866
# 7/31/15  0.105392  0.057895 -0.022693  ... -0.004918  0.045705  0.096071
#
#               EIX      SBUX       MCO       HII        RL       LNT       AXP
# Date
# 3/31/15       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4/30/15 -0.024492  0.047096  0.035838 -0.061077  0.014524 -0.031611 -0.008577
# 5/31/15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6/30/15 -0.081105  0.084925  0.007206 -0.141581 -0.004303 -0.045477  0.007241
# 7/31/15  0.079705  0.080381  0.022879  0.042810 -0.048882  0.075432 -0.021358
#
# [5 rows x 100 columns]

# %%
monthly_df_daily_returns.shape
# Out:
# (58, 100)

# %%
monthly_df_daily_returns.dropna(inplace = True)
monthly_df_daily_returns.shape
# Out:
# (57, 100)

# %%
monthly_df_daily_returns.index = pd.DatetimeIndex(monthly_df_daily_returns.index)

# %%
monthly_df_daily_returns.index
# Out:
# DatetimeIndex(['2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31',
#                '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30',
#                '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30',
#                '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31',
#                '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31',
#                '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
#                '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31',
#                '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
#                '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30',
#                '2019-12-31'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
ffm_csv_path = Path('F-F_Research_Data_Factors.csv')
ffm_data = pd.read_csv(ffm_csv_path, index_col='Date')
ffm_data.shape
# Out:
# (57, 4)

# %%
ffm_data.tail()
# Out:
#             Mkt-RF   SMB   HML    RF
# Date
# 8/31/2019    -2.58 -2.41 -4.99  0.16
# 9/30/2019     1.44 -0.90  6.71  0.18
# 10/31/2019    2.06  0.25 -2.07  0.15
# 11/30/2019    3.87  0.87 -1.86  0.12
# 12/31/2019    2.77  0.69  1.82  0.14

# %%
ffm_data.index
# Out:
# Index(['4/30/2015', '5/31/2015', '6/30/2015', '7/31/2015', '8/31/2015',
#        '9/30/2015', '10/31/2015', '11/30/2015', '12/31/2015', '1/31/2016',
#        '2/29/2016', '3/31/2016', '4/30/2016', '5/31/2016', '6/30/2016',
#        '7/31/2016', '8/31/2016', '9/30/2016', '10/31/2016', '11/30/2016',
#        '12/31/2016', '1/31/2017', '2/28/2017', '3/31/2017', '4/30/2017',
#        '5/31/2017', '6/30/2017', '7/31/2017', '8/31/2017', '9/30/2017',
#        '10/31/2017', '11/30/2017', '12/31/2017', '1/31/2018', '2/28/2018',
#        '3/31/2018', '4/30/2018', '5/31/2018', '6/30/2018', '7/31/2018',
#        '8/31/2018', '9/30/2018', '10/31/2018', '11/30/2018', '12/31/2018',
#        '1/31/2019', '2/28/2019', '3/31/2019', '4/30/2019', '5/31/2019',
#        '6/30/2019', '7/31/2019', '8/31/2019', '9/30/2019', '10/31/2019',
#        '11/30/2019', '12/31/2019'],
#       dtype='object', name='Date')

# %%
ffm_data.index = pd.DatetimeIndex(ffm_data.index)

# %%
reg = linear_model.LinearRegression()

# %%
reg = linear_model.LinearRegression()
fit = reg.fit(X=ffm_data[['SMB','HML','RF']],
              y=monthly_df_daily_returns.AAPL)

# %%
fit.coef_
# Out:
# array([ 0.00543362, -0.00148654,  0.14036053])

# %%
import statsmodels.api as sm
from statsmodels.regression import linear_model as lm

# %%
results_dict = {}
params = {}

# %%
for ticker in monthly_df_daily_returns.columns:
    results_dict[ticker] = lm.OLS(endog=monthly_df_daily_returns.loc[:,ticker],
                  exog=sm.add_constant(ffm_data[['SMB','HML','RF']])).fit()
    
    params[ticker] = results_dict[ticker].params
# Out:
# C:\Users\nikki\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
temp_var = results_dict['AAPL']

# %%
temp_var

# %%
params
# Out:
# {'DXC': const    0.061115
#  SMB      0.008115
#  HML     -0.011236
#  RF      -0.514286
#  dtype: float64, 'BBY': const    0.020687
#  SMB      0.002466
#  HML      0.004299
#  RF       0.030096
#  dtype: float64, 'AMG': const    0.001608
#  SMB      0.007604
#  HML      0.002682
#  RF      -0.137121
#  dtype: float64, 'CNP': const    0.014205
#  SMB     -0.000845
#  HML     -0.000934
#  RF      -0.056507
#  dtype: float64, 'WMT': const   -0.001128
#  SMB     -0.006024
#  HML      0.000564
#  RF       0.116778
#  dtype: float64, 'MRK': const    0.001938
#  SMB      0.000793
#  HML      0.000644
#  RF       0.117982
#  dtype: float64, 'NEM': const    0.024880
#  SMB     -0.000555
#  HML     -0.001032
#  RF      -0.081088
#  dtype: float64, 'VFC': const   -0.005603
#  SMB      0.001496
#  HML      0.001982
#  RF       0.194394
#  dtype: float64, 'MDT': const    0.003613
#  SMB      0.002112
#  HML     -0.006037
#  RF       0.053335
#  dtype: float64, 'HST': const    0.003580
#  SMB      0.010678
#  HML      0.003143
#  RF       0.041342
#  dtype: float64, 'MTD': const    0.019082
#  SMB      0.003871
#  HML     -0.003831
#  RF      -0.015325
#  dtype: float64, 'CCI': const    0.009123
#  SMB     -0.000177
#  HML     -0.004714
#  RF       0.036494
#  dtype: float64, 'KMI': const   -0.028784
#  SMB      0.011627
#  HML      0.005967
#  RF       0.326829
#  dtype: float64, 'RMD': const    0.005136
#  SMB      0.003046
#  HML     -0.002828
#  RF       0.136939
#  dtype: float64, 'LUV': const    0.012349
#  SMB      0.005423
#  HML      0.000878
#  RF      -0.037022
#  dtype: float64, 'NWS': const    0.000269
#  SMB      0.002875
#  HML      0.003523
#  RF       0.041666
#  dtype: float64, 'AMGN': const    0.009304
#  SMB      0.003265
#  HML     -0.002212
#  RF       0.028785
#  dtype: float64, 'APD': const    0.000252
#  SMB      0.002905
#  HML      0.002213
#  RF       0.156691
#  dtype: float64, 'TGT': const   -0.011409
#  SMB      0.000704
#  HML      0.009845
#  RF       0.324107
#  dtype: float64, 'MYL': const   -0.003919
#  SMB      0.004287
#  HML      0.001962
#  RF      -0.083962
#  dtype: float64, 'GPC': const    0.002508
#  SMB      0.005500
#  HML      0.000083
#  RF       0.051637
#  dtype: float64, 'FCX': const    0.004494
#  SMB      0.012418
#  HML      0.011996
#  RF       0.069110
#  dtype: float64, 'KO': const    0.002351
#  SMB     -0.005048
#  HML      0.001910
#  RF       0.070731
#  dtype: float64, 'DISCK': const   -0.008075
#  SMB      0.003284
#  HML      0.003561
#  RF       0.170151
#  dtype: float64, 'FISV': const    0.014776
#  SMB      0.002540
#  HML     -0.001280
#  RF       0.062496
#  dtype: float64, 'ACN': const    0.015622
#  SMB      0.002699
#  HML     -0.000629
#  RF       0.026739
#  dtype: float64, 'SRCL': const   -0.024769
#  SMB      0.000526
#  HML      0.001228
#  RF       0.189615
#  dtype: float64, 'IT': const    0.014402
#  SMB      0.007237
#  HML      0.000695
#  RF       0.002592
#  dtype: float64, 'PHM': const    0.003328
#  SMB      0.005700
#  HML      0.002529
#  RF       0.137323
#  dtype: float64, 'ALB': const    0.037976
#  SMB      0.002709
#  HML     -0.002182
#  RF      -0.308654
#  dtype: float64, 'AAPL': const    0.008246
#  SMB      0.005434
#  HML     -0.001487
#  RF       0.140361
#  dtype: float64, 'EFX': const    0.012375
#  SMB      0.005482
#  HML     -0.005962
#  RF      -0.021729
#  dtype: float64, 'FE': const   -0.002917
#  SMB     -0.002028
#  HML      0.000768
#  RF       0.148803
#  dtype: float64, 'COST': const    0.004697
#  SMB     -0.002089
#  HML     -0.000602
#  RF       0.111257
#  dtype: float64, 'GWW': const    0.003480
#  SMB      0.006669
#  HML      0.003160
#  RF       0.117593
#  dtype: float64, 'M': const   -0.012365
#  SMB      0.005714
#  HML      0.004129
#  RF       0.030791
#  dtype: float64, 'CRM': const    0.017188
#  SMB      0.000440
#  HML     -0.005693
#  RF      -0.015475
#  dtype: float64, 'LKQ': const    0.014119
#  SMB      0.005254
#  HML      0.001539
#  RF      -0.044887
#  dtype: float64, 'AON': const    0.008955
#  SMB      0.002092
#  HML      0.000802
#  RF       0.082234
#  dtype: float64, 'PEP': const    0.005069
#  SMB     -0.002564
#  HML      0.000210
#  RF       0.047505
#  dtype: float64, 'RJF': const    0.020784
#  SMB      0.010288
#  HML      0.004507
#  RF      -0.059371
#  dtype: float64, 'ORCL': const    0.002123
#  SMB      0.002930
#  HML      0.000697
#  RF       0.053539
#  dtype: float64, 'MHK': const    0.016080
#  SMB      0.010295
#  HML     -0.007010
#  RF      -0.213273
#  dtype: float64, 'PPL': const    0.006665
#  SMB     -0.001793
#  HML     -0.000347
#  RF       0.004218
#  dtype: float64, 'FMC': const    0.013770
#  SMB      0.011942
#  HML     -0.000161
#  RF       0.067034
#  dtype: float64, 'OKE': const    0.011363
#  SMB      0.008289
#  HML      0.004723
#  RF       0.100778
#  dtype: float64, 'EQR': const   -0.004598
#  SMB      0.001556
#  HML     -0.000774
#  RF       0.128613
#  dtype: float64, 'RCL': const    0.018184
#  SMB      0.003593
#  HML     -0.005539
#  RF      -0.052823
#  dtype: float64, 'IRM': const    0.004480
#  SMB      0.003335
#  HML     -0.001135
#  RF       0.012720
#  dtype: float64, 'BA': const    0.022195
#  SMB      0.000031
#  HML      0.000687
#  RF      -0.034636
#  dtype: float64, 'ABC': const   -0.005926
#  SMB      0.002891
#  HML     -0.000770
#  RF       0.059366
#  dtype: float64, 'GIS': const   -0.001165
#  SMB      0.000330
#  HML      0.001284
#  RF       0.059891
#  dtype: float64, 'SYF': const    0.004555
#  SMB      0.010937
#  HML      0.003822
#  RF       0.075372
#  dtype: float64, 'BMY': const    0.005970
#  SMB      0.003685
#  HML     -0.001674
#  RF      -0.006413
#  dtype: float64, 'ADBE': const    0.030652
#  SMB      0.004416
#  HML     -0.006104
#  RF      -0.037800
#  dtype: float64, 'SNPS': const    0.014860
#  SMB      0.004688
#  HML     -0.001367
#  RF       0.078959
#  dtype: float64, 'BWA': const   -0.006304
#  SMB      0.003931
#  HML      0.002263
#  RF       0.073987
#  dtype: float64, 'MSI': const    0.011351
#  SMB      0.005567
#  HML      0.002309
#  RF       0.109046
#  dtype: float64, 'COF': const    0.008250
#  SMB      0.007530
#  HML      0.006438
#  RF       0.046696
#  dtype: float64, 'LYB': const    0.011198
#  SMB      0.007446
#  HML      0.007150
#  RF      -0.001870
#  dtype: float64, 'RTN': const    0.023770
#  SMB      0.003074
#  HML     -0.002996
#  RF      -0.098937
#  dtype: float64, 'FFIV': const    0.012918
#  SMB      0.000476
#  HML     -0.000948
#  RF      -0.092361
#  dtype: float64, 'HLT': const    0.002100
#  SMB      0.003407
#  HML     -0.000545
#  RF       0.130048
#  dtype: float64, 'CVS': const   -0.007875
#  SMB     -0.001085
#  HML      0.000170
#  RF       0.070387
#  dtype: float64, 'NEE': const    0.011969
#  SMB     -0.003622
#  HML     -0.002750
#  RF       0.056764
#  dtype: float64, 'KMX': const   -0.006193
#  SMB      0.002969
#  HML      0.003877
#  RF       0.173115
#  dtype: float64, 'INCY': const    0.011105
#  SMB      0.013491
#  HML     -0.007168
#  RF      -0.069457
#  dtype: float64, 'MGM': const    0.018770
#  SMB      0.004335
#  HML      0.000645
#  RF      -0.065056
#  dtype: float64, 'AES': const   -0.004478
#  SMB      0.005141
#  HML     -0.000578
#  RF       0.213484
#  dtype: float64, 'GM': const    0.004343
#  SMB      0.008198
#  HML      0.002905
#  RF       0.048407
#  dtype: float64, 'FDX': const    0.017616
#  SMB      0.007917
#  HML      0.000101
#  RF      -0.158677
#  dtype: float64, 'ADP': const    0.009664
#  SMB      0.004764
#  HML      0.000484
#  RF       0.076825
#  dtype: float64, 'HOLX': const    0.007791
#  SMB      0.002793
#  HML      0.001924
#  RF       0.036097
#  dtype: float64, 'NRG': const    0.003305
#  SMB      0.003679
#  HML     -0.001152
#  RF       0.151136
#  dtype: float64, 'NBL': const   -0.012925
#  SMB      0.011915
#  HML      0.010558
#  RF       0.157235
#  dtype: float64, 'MSFT': const    0.026299
#  SMB     -0.001488
#  HML      0.001466
#  RF       0.018309
#  dtype: float64, 'COG': const   -0.002765
#  SMB      0.008025
#  HML     -0.000324
#  RF      -0.013397
#  dtype: float64, 'OXY': const    0.009196
#  SMB      0.008619
#  HML     -0.000304
#  RF      -0.128805
#  dtype: float64, 'GOOGL': const    0.024805
#  SMB     -0.001593
#  HML     -0.004908
#  RF      -0.103449
#  dtype: float64, 'GS': const    0.010831
#  SMB      0.004155
#  HML      0.008533
#  RF       0.002233
#  dtype: float64, 'HRB': const    0.000201
#  SMB      0.001534
#  HML     -0.005913
#  RF      -0.015976
#  dtype: float64, 'AJG': const    0.009925
#  SMB      0.000845
#  HML      0.001017
#  RF       0.071882
#  dtype: float64, 'CINF': const    0.010534
#  SMB      0.001748
#  HML      0.002512
#  RF       0.072763
#  dtype: float64, 'TXN': const    0.018136
#  SMB      0.004924
#  HML      0.000477
#  RF       0.019306
#  dtype: float64, 'ETN': const    0.006533
#  SMB      0.008304
#  HML      0.001894
#  RF       0.073624
#  dtype: float64, 'EXPE': const    0.014756
#  SMB     -0.000492
#  HML     -0.002503
#  RF      -0.111228
#  dtype: float64, 'TMO': const    0.010040
#  SMB      0.000351
#  HML     -0.004001
#  RF       0.073771
#  dtype: float64, 'BSX': const    0.014928
#  SMB      0.002898
#  HML     -0.006961
#  RF       0.020366
#  dtype: float64, 'CTAS': const    0.019509
#  SMB      0.007091
#  HML      0.000123
#  RF       0.066158
#  dtype: float64, 'WBA': const    0.002251
#  SMB     -0.002538
#  HML      0.001442
#  RF      -0.048373
#  dtype: float64, 'UNH': const    0.022822
#  SMB      0.004415
#  HML     -0.002016
#  RF      -0.041093
#  dtype: float64, 'HSY': const   -0.002206
#  SMB     -0.007348
#  HML     -0.001702
#  RF       0.121551
#  dtype: float64, 'FB': const    0.025092
#  SMB      0.005926
#  HML     -0.007666
#  RF      -0.086029
#  dtype: float64, 'EIX': const    0.006008
#  SMB     -0.005985
#  HML      0.001459
#  RF       0.028393
#  dtype: float64, 'SBUX': const    0.003680
#  SMB     -0.000546
#  HML      0.001507
#  RF       0.123041
#  dtype: float64, 'MCO': const    0.009267
#  SMB      0.005686
#  HML     -0.002955
#  RF       0.102357
#  dtype: float64, 'HII': const    0.021025
#  SMB      0.001957
#  HML     -0.000530
#  RF      -0.080412
#  dtype: float64, 'RL': const   -0.005554
#  SMB      0.010390
#  HML      0.003945
#  RF       0.144702
#  dtype: float64, 'LNT': const    0.009608
#  SMB     -0.001865
#  HML     -0.001128
#  RF       0.035915
#  dtype: float64, 'AXP': const    0.003565
#  SMB      0.002467
#  HML      0.003805
#  RF       0.104800
#  dtype: float64}

# %%
temp_df = pd.DataFrame.from_dict(params, orient='index', columns = ['const', 'SMB', 'HML', 'RF'])
temp_df
# Out:
#         const       SMB       HML        RF
# DXC  0.061115  0.008115 -0.011236 -0.514286
# BBY  0.020687  0.002466  0.004299  0.030096
# AMG  0.001608  0.007604  0.002682 -0.137121
# CNP  0.014205 -0.000845 -0.000934 -0.056507
# WMT -0.001128 -0.006024  0.000564  0.116778
# ..        ...       ...       ...       ...
# MCO  0.009267  0.005686 -0.002955  0.102357
# HII  0.021025  0.001957 -0.000530 -0.080412
# RL  -0.005554  0.010390  0.003945  0.144702
# LNT  0.009608 -0.001865 -0.001128  0.035915
# AXP  0.003565  0.002467  0.003805  0.104800
#
# [100 rows x 4 columns]

# %%
#temp_df_data = Path("../CollaborativeProject1/")

#temp_df.to_csv(Path"../CollaborativeProject1")

temp_df.to_csv('params.csv')
